# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoSReco/intro_python_para_economistas/blob/main/script_python_5_Analisis_Datos_Pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **5. Introducción al manejo de datos con `Pandas`🐼 Parte 2**
#
# ## **5.4 Importar y explorar diferentes tipos de datos**

# %% [markdown]
# #### **5.4.1 Conjuntos de datos de librerías (Woolridge, Causal Data, Scikit-learn)**
#
# En Python es posible importar diferentes tipos de conjuntos de datos utilizando librerías como Woolridge, CausalData, Datareade etc. Estas herramientas nos permitirán acceder a conjuntos de datos estructurados provenientes de fuentes económicas, financieras y de aprendizaje automático.
#
# * **Wooldridge**
#
# Esta libreria nos permite utilizar 111 conjuntos  de datos los cuales son utilizados en los ejemplos del libro  ***J.M. Wooldridge (2019) Introductory Econometrics: A Modern Approach***.

# %%
pip install wooldridge

# %%
import wooldridge as wd

print("\n### Wooldridge: Lista de Conjuntos de Datos Disponibles ###")
print(wd.data())
# Out:
# ### Wooldridge: Lista de Conjuntos de Datos Disponibles ###
#   J.M. Wooldridge (2019) Introductory Econometrics: A Modern Approach,
#   Cengage Learning, 6th edition.
#
#   401k       401ksubs    admnrev       affairs     airfare
#   alcohol    apple       approval      athlet1     athlet2
#   attend     audit       barium        beauty      benefits
#   beveridge  big9salary  bwght         bwght2      campus
#   card       catholic    cement        census2000  ceosal1
#   ceosal2    charity     consump       corn        countymurders
#   cps78_85   cps91       crime1        crime2      crime3
#   crime4     discrim     driving       earns       econmath
#   elem94_95  engin       expendshares  ezanders    ezunem
#   fair       fertil1     fertil2       fertil3     fish
#   fringe     gpa1        gpa2          gpa3        happiness
#   hprice1    hprice2     hprice3       hseinv      htv
#   infmrt     injury      intdef        intqrt      inven
# ...

# %%
#Cargar un conjunto de datos específico

description_wagepan = wd.data('alcohol', description= True)

description_wagepan
# Out:
# name of dataset: alcohol
# no of variables: 33
# no of observations: 9822
#
# +------------+----------------------------------------------------+
# | variable   | label                                              |
# +------------+----------------------------------------------------+
# | abuse      | =1 if abuse alcohol                                |
# | status     | out of workforce = 1; unemployed = 2, employed = 3 |
# | unemrate   | state unemployment rate                            |
# | age        | age in years                                       |
# | educ       | years of schooling                                 |
# | married    | =1 if married                                      |
# | famsize    | family size                                        |
# | white      | =1 if white                                        |
# | exhealth   | =1 if in excellent health                          |
# | vghealth   | =1 if in very good health                          |
# ...

# %%
df_wagepan = wd.data('wagepan')
df_wagepan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4360 entries, 0 to 4359
# Data columns (total 44 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   nr        4360 non-null   int64
#  1   year      4360 non-null   int64
#  2   agric     4360 non-null   int64
#  3   black     4360 non-null   int64
#  4   bus       4360 non-null   int64
#  5   construc  4360 non-null   int64
#  6   ent       4360 non-null   int64
#  7   exper     4360 non-null   int64
#  8   fin       4360 non-null   int64
#  9   hisp      4360 non-null   int64
#  10  poorhlth  4360 non-null   int64
#  11  hours     4360 non-null   int64
#  12  manuf     4360 non-null   int64
#  13  married   4360 non-null   int64
#  14  min       4360 non-null   int64
#  15  nrthcen   4360 non-null   int64
#  16  nrtheast  4360 non-null   int64
#  17  occ1      4360 non-null   int64
#  18  occ2      4360 non-null   int64
#  19  occ3      4360 non-null   int64
# ...

# %% [markdown]
# * **Causal Data**
#
# [El Efecto: Una Indtroducción al Diseño de Investigación y Causalidad](https://theeffectbook.net/)

# %%
pip install causaldata
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 26.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for causaldata: filename=causaldata-0.1.5-py3-none-any.whl size=2767647 sha256=6d699438947f56673f0f6ff28841121c033b5ac39f367c77e3fc29939bde2e4f
#   Stored in directory: /root/.cache/pip/wheels/a1/03/f7/4feb3ae1964932dc58fe5acfc4bdb02d5df05dd6b8aa2d8437
# Successfully built causaldata
# ...

# %%
import causaldata
print(dir(causaldata))
# Out:
# ['Mroz', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'abortion', 'adult_services', 'auto', 'avocado', 'black_politicians', 'castle', 'close_college', 'close_elections_lmb', 'cps_mixtape', 'credit_cards', 'gapminder', 'google_stock', 'gov_transfers', 'gov_transfers_density', 'greek_data', 'mortgages', 'nhefs', 'nhefs_codebook', 'nhefs_complete', 'nsw_mixtape', 'organ_donations', 'restaurant_inspections', 'ri', 'scorecard', 'snow', 'social_insure', 'texas', 'thornton_hiv', 'titanic', 'training_bias_reduction', 'training_example', 'yule']

# %% [markdown]
# **Carga de datos en Causal Data**

# %%
#Carga de datos
df_organs = causaldata.organ_donations.load_pandas().data

# %%
print(df_organs.info())
print(df_organs.describe())
df_organs
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        162 non-null    object
#  1   Quarter      162 non-null    object
#  2   Rate         162 non-null    float64
#  3   Quarter_Num  162 non-null    int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 5.2+ KB
# None
#              Rate  Quarter_Num
# count  162.000000   162.000000
# mean     0.445048     3.500000
# std      0.153353     1.713121
# min      0.122900     1.000000
# 25%      0.334600     2.000000
# 50%      0.439700     3.500000
# 75%      0.564450     5.000000
# max      0.790000     6.000000
#        State Quarter    Rate  Quarter_Num
# 0     Alaska  Q42010  0.7500            1
# 1     Alaska  Q12011  0.7700            2
# 2     Alaska  Q22011  0.7700            3
# 3     Alaska  Q32011  0.7800            4
# 4     Alaska  Q42011  0.7800            5
# ...

# %% [markdown]
# **Fuente del data set**

# %%
#Fuente del data set
print(causaldata.organ_donations.DESCRLONG)
print(causaldata.organ_donations.SOURCE)
# Out:
# The organ_donation data contains data from Kessler and Roth (2014) on organ donation rates by state and quarter. The state of California enacted an active-choice phrasing for their organ donation sign-up questoin in Q32011. The only states included in the data are California and those that can serve as valid controls; see Kessler and Roth (2014). This data set is used in the Difference-in-Differences chapter of The Effect.
#
# Kessler, J.B. and Roth, A.E., 2014. Don't take 'no' for an answer: An experiment with actual organ donor registrations. National Bureau of Economic Research working paper No. 20378. https://www.nber.org/papers/w20378

# %%
#Fuente del data set
print(causaldata.credit_cards.DESCRLONG)
print(causaldata.credit_cards.SOURCE)
# Out:
# Data from the UCI Machine Learning Repository on Taiwanese credit card holders, the amount of their credit card bill, and whether their payment was late. This data is used in the Matching chapter of The Effect by Huntington-Klein.
#
# Lichman, Moshe. 2013. UCI Machine Learning Repository.

# %%
df_cc = causaldata.credit_cards.load_pandas().data
df_cc
# Out:
#        LateSept  LateApril  BillApril  AGE
# 0             1          0      0.000   24
# 1             0          1      3.261   26
# 2             0          0     15.549   34
# 3             0          0     29.547   37
# 4             0          0     19.131   57
# ...         ...        ...        ...  ...
# 29995         0          0     15.980   39
# 29996         0          0      0.000   43
# 29997         1          0     19.357   37
# 29998         1          0     48.944   41
# 29999         0          0     15.313   46
#
# [30000 rows x 4 columns]

# %% [markdown]
# * **Scikit-learn**
#
# Modelos de regressión y clasificación para análisis predictivo de datos.
#
# [Scikit-learn](https://scikit-learn.org/stable/)
#
#
# * load_iris(): Datos de clasificación de flores Iris.
#
# * load_digits(): Imágenes de dígitos escritos a mano.
#
# * load_wine(): Características químicas de vinos.
#
# * fetch_california_housing(): Datos de viviendas en California.

# %%
from sklearn import datasets
import pandas as pd

# %%
calif_hs = datasets.fetch_california_housing()
print(calif_hs)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
calif_hs.feature_names
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude']

# %%
df_calif_hs = pd.DataFrame(data= calif_hs.data,
                           columns = calif_hs.feature_names)
df_calif_hs
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
# Acceder a características del dataset
print(df_calif_hs.info())
print(df_calif_hs.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
# dtypes: float64(8)
# memory usage: 1.3 MB
# None
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# ...

# %% [markdown]
# * **DataReader**
#
# Paquetería que nos permite acceder de forma fácil y flexible a fuentes de datos:
#
# * Yahoo Finance para datos de acciones
# * Banco Mundial para indicadores económicos
# * Tasas de cambio de divisas
# * Índices bursátiles como S&P 500 y NASDAQ
#
# **Beneficios**
#
# - Acceso fácil a datos financieros
# - Descarga automática de información actualizada
# - Integración directa con Pandas para análisis
#
# **Ejemplos:**
#
# - **Banco Mundial**

# %%
import pandas_datareader as pdr
#from datetime import datetime
import pandas_datareader.wb as wb

# %%
df_meta_wb = wb.search('')

print(df_meta_wb['topics'].value_counts().head(10))

#Filtramos DF  relaciones con probreza
df_meta_wb[(df_meta_wb['topics'] == 'Economy & Growth') & df_meta_wb['name'].str.contains('GDP') ]
# Out:
# topics
#                              17502
# Social Protection & Labor     2042
# Health                         568
# Education                      527
# External Debt                  485
# Economy & Growth               209
# Financial Sector               171
# Poverty                        138
# Public Sector                  133
# Gender                         123
# Name: count, dtype: int64
#                        id                                               name  \
# 688       6.0.GDP_current                                    GDP (current $)
# 689        6.0.GDP_growth                              GDP growth (annual %)
# 690           6.0.GDP_usd                              GDP (constant 2005 $)
# 691    6.0.GDPpc_constant  GDP per capita, PPP (constant 2011 internation...
# 1929    BN.CAB.XOKA.GD.ZS                 Current account balance (% of GDP)
# 1959    BN.KLT.PRVT.GD.ZS            Private capital flows, total (% of GDP)
# ...

# %%
# Ejemplo 1: Recuperar datos económicos del Banco Mundial
df_pob_tot = wb.download( indicator= 'SP.POP.TOTL')
df_pob_tot
# Out:
# <ipython-input-140-8583881654db>:2: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df_pob_tot = wb.download( indicator= 'SP.POP.TOTL')
#                     SP.POP.TOTL
# country       year
# Canada        2005     32242732
#               2004     31938807
#               2003     31642461
# Mexico        2005    105811504
#               2004    104394131
#               2003    102978515
# United States 2005    295516599
#               2004    292805298
#               2003    290107933

# %%
#Lista de paises en Latam
abv_latam = ["ARG", "BOL", "BRA", "CHL", "COL", "CRI", "CUB", "DOM", "ECU",
             "SLV", "GTM", "HND", "MEX", "NIC", "PAN", "PRY", "PER", "PRI",
             "URY", "VEN"]


#Poblacion total de paises
df_pob_tot_LA = wb.download( indicator= ['SP.POP.TOTL',
                                         'SI.POV.GINI',
                                         'NY.GDP.MKTP.KD'],
                              country= abv_latam ,
                              start= 2018,
                              end= 2023)
#Reset index
df_pob_tot_LA = df_pob_tot_LA.reset_index()
#Cambiar nombres de columnas
df_pob_tot_LA.rename(columns = {'SP.POP.TOTL': 'Poblacion total', 'SI.POV.GINI':'Gini', 'NY.GDP.MKTP.KD':'GDP'})
# Out:
# <ipython-input-143-07232383a61c>:8: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df_pob_tot_LA = wb.download( indicator= ['SP.POP.TOTL',
#            country  year  Poblacion total  Gini           GDP
# 0        Argentina  2018         44654882  41.7  5.831181e+11
# 1        Argentina  2019         44973465  43.3  5.714507e+11
# 2        Argentina  2020         45191965  42.7  5.148743e+11
# 3        Argentina  2021         45312281  42.4  5.686366e+11
# 4        Argentina  2022         45407904  40.7  5.986030e+11
# ..             ...   ...              ...   ...           ...
# 115  Venezuela, RB  2019         28938098   NaN           NaN
# 116  Venezuela, RB  2020         28444077   NaN           NaN
# 117  Venezuela, RB  2021         28237826   NaN           NaN
# 118  Venezuela, RB  2022         28213017   NaN           NaN
# ...

# %%
df_pob_tot_LA[ df_pob_tot_LA['country'].isin(['Mexico', 'Argentina', 'Colombia'])  ]
# Out:
#       country  year  SP.POP.TOTL  SI.POV.GINI  NY.GDP.MKTP.KD
# 0   Argentina  2018     44654882         41.7    5.831181e+11
# 1   Argentina  2019     44973465         43.3    5.714507e+11
# 2   Argentina  2020     45191965         42.7    5.148743e+11
# 3   Argentina  2021     45312281         42.4    5.686366e+11
# 4   Argentina  2022     45407904         40.7    5.986030e+11
# 5   Argentina  2023     45538401          NaN    5.889595e+11
# 24   Colombia  2018     49024465         50.4    3.114792e+11
# 25   Colombia  2019     49907985         51.3    3.214056e+11
# 26   Colombia  2020     50629997         53.5    2.983097e+11
# 27   Colombia  2021     51188173         55.1    3.305307e+11
# 28   Colombia  2022     51737944         54.8    3.546227e+11
# 29   Colombia  2023     52321152          NaN    3.567873e+11
# 72     Mexico  2018    124573711         46.0    1.282719e+12
# 73     Mexico  2019    125762982          NaN    1.277682e+12
# ...

# %% [markdown]
# * **FRED: Federal Reserve bank of St. Louis logo**

# %%
#import pandas_datareader.fred as fred
from datetime import datetime

start_date = datetime(2023, 1, 1)

end_date = datetime(2025, 1, 1)


# Descargar los datos de FRED
series_unrate = pdr.get_data_fred('UNRATE', start=start_date, end=end_date)

# Mostrar las primeras filas
print(series_unrate)
# Out:
#             UNRATE
# DATE
# 2023-01-01     3.5
# 2023-02-01     3.6
# 2023-03-01     3.5
# 2023-04-01     3.4
# 2023-05-01     3.6
# 2023-06-01     3.6
# 2023-07-01     3.5
# 2023-08-01     3.7
# 2023-09-01     3.8
# 2023-10-01     3.9
# 2023-11-01     3.7
# 2023-12-01     3.8
# 2024-01-01     3.7
# 2024-02-01     3.9
# 2024-03-01     3.9
# 2024-04-01     3.9
# 2024-05-01     4.0
# 2024-06-01     4.1
# 2024-07-01     4.2
# 2024-08-01     4.2
# 2024-09-01     4.1
# 2024-10-01     4.1
# 2024-11-01     4.2
# 2024-12-01     4.1
# 2025-01-01     4.0

# %%
#indicadores
series = ['CPIAUCSL', 'UNRATE', 'GDP']

#DF download
df_EU_ind = pdr.get_data_fred(series,
                              start=start_date,
                              end=end_date)

#DF
df_EU_ind
# Out:
#             CPIAUCSL  UNRATE        GDP
# DATE
# 2023-01-01   300.456     3.5  27164.359
# 2023-02-01   301.476     3.6        NaN
# 2023-03-01   301.643     3.5        NaN
# 2023-04-01   302.858     3.4  27453.815
# 2023-05-01   303.316     3.6        NaN
# 2023-06-01   304.099     3.6        NaN
# 2023-07-01   304.615     3.5  27967.697
# 2023-08-01   306.138     3.7        NaN
# 2023-09-01   307.374     3.8        NaN
# 2023-10-01   307.653     3.9  28296.967
# 2023-11-01   308.087     3.7        NaN
# 2023-12-01   308.735     3.8        NaN
# 2024-01-01   309.794     3.7  28624.069
# 2024-02-01   311.022     3.9        NaN
# 2024-03-01   312.107     3.9        NaN
# 2024-04-01   313.016     3.9  29016.714
# 2024-05-01   313.140     4.0        NaN
# 2024-06-01   313.131     4.1        NaN
# 2024-07-01   313.566     4.2  29374.914
# 2024-08-01   314.131     4.2        NaN
# 2024-09-01   314.851     4.1        NaN
# 2024-10-01   315.564     4.1  29719.647
# ...

# %% [markdown]
# **Extracción de Datos Financieros con `yfinance`**
#
# Este paquete es muy útil para obtener información detallada sobre acciones, ETFs, divisas, y más, con solo unas líneas de código.

# %%
pip install yfinance

# %%
import yfinance as yf

# %% [markdown]
# 1 . Con yfinance, cada activo financiero se representa como un objeto llamado **Ticker**.
#
# Este objeto nos permite acceder a la información detallada de la acción (o cualquier otro instrumento financiero).

# %%
stock_google = yf.Ticker("GOOGL")
stock_google
# Out:
# yfinance.Ticker object <GOOGL>

# %% [markdown]
# El método `history()` nos permite obtener los precios históricos de una acción, que incluye las columnas de apertura (Open), cierre (Close), máximo (High), mínimo (Low), volumen (Volume) y cierre ajustado (Adj Close).

# %%
#1Y
historical_data = stock_google.history(period="1y")

#Podemos cambiar el parámetro:'1d', '1mo', '1y', '5y'


# Tipo y datos
print(type(historical_data))
historical_data.info()
historical_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 250 entries, 2024-03-27 00:00:00-04:00 to 2025-03-26 00:00:00-04:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          250 non-null    float64
#  1   High          250 non-null    float64
#  2   Low           250 non-null    float64
#  3   Close         250 non-null    float64
#  4   Volume        250 non-null    int64
#  5   Dividends     250 non-null    float64
#  6   Stock Splits  250 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 15.6 KB
#                                  Open        High         Low       Close  \
# Date
# 2024-03-27 00:00:00-04:00  150.460637  150.918455  148.191487  150.152115
# 2024-03-28 00:00:00-04:00  150.132232  150.709459  149.455459  150.211838
# 2024-04-01 00:00:00-04:00  149.972989  154.998963  149.893368  154.750153
# ...

# %% [markdown]
# **Datos de Finanzas y Reportes de la Empresa**
#
# Reportes de la empresa, como el balance general, la cuenta de resultados (ingresos y ganancias) y el flujo de caja.

# %%
#Estados de resultados
df_income_statement = stock_google.financials

# Mostrar el estado de resultados
print(df_income_statement)
# Out:
#                                                         2024-12-31  \
# Tax Effect Of Unusual Items                            370968000.0
# Tax Rate For Calcs                                           0.164
# Normalized EBITDA                                   133132000000.0
# Total Unusual Items                                   2262000000.0
# Total Unusual Items Excluding Goodwill                2262000000.0
# Net Income From Continuing Operation Net Minori...  100118000000.0
# Reconciled Depreciation                              15311000000.0
# Reconciled Cost Of Revenue                          146306000000.0
# EBITDA                                              135394000000.0
# EBIT                                                120083000000.0
# Net Interest Income                                   4214000000.0
# Interest Expense                                       268000000.0
# Interest Income                                       4482000000.0
# ...

# %%
#Flujo de caja
cashflow = stock_google.cashflow
balance_sheet = stock_google.balance_sheet
recommendations = stock_google.recommendations
#Balance
print(cashflow, balance_sheet, recommendations)
# Out:
#                                                     2024-12-31  \
# Free Cash Flow                                   72764000000.0
# Repurchase Of Capital Stock                     -62222000000.0
# Repayment Of Debt                               -12701000000.0
# Issuance Of Debt                                 13589000000.0
# Capital Expenditure                             -52535000000.0
# Income Tax Paid Supplemental Data                          NaN
# End Cash Position                                23466000000.0
# Beginning Cash Position                          24048000000.0
# Effect Of Exchange Rate Changes                   -612000000.0
# Changes In Cash                                     30000000.0
# Financing Cash Flow                             -79733000000.0
# Cash Flow From Continuing Financing Activities  -79733000000.0
# Net Other Financing Charges                       1154000000.0
# Proceeds From Stock Option Exercised            -12190000000.0
# ...

# %%
# Crear un objeto Ticker para Apple
stock_multi = yf.Tickers(['AAPL', 'GOOGL', 'AMZN' ])
#Cargamos datos de precios históricos de activos
df_multi = stock_multi.history(period="1y")
#DF info
print(df_multi.info())
df_multi
# Out:
# [*********************100%***********************]  3 of 3 completed
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 250 entries, 2024-03-27 to 2025-03-26
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Close, AAPL)          250 non-null    float64
#  1   (Close, AMZN)          250 non-null    float64
#  2   (Close, GOOGL)         250 non-null    float64
#  3   (Dividends, AAPL)      250 non-null    float64
#  4   (Dividends, AMZN)      250 non-null    float64
#  5   (Dividends, GOOGL)     250 non-null    float64
#  6   (High, AAPL)           250 non-null    float64
#  7   (High, AMZN)           250 non-null    float64
#  8   (High, GOOGL)          250 non-null    float64
#  9   (Low, AAPL)            250 non-null    float64
#  10  (Low, AMZN)            250 non-null    float64
#  11  (Low, GOOGL)           250 non-null    float64
# ...

# %% [markdown]
# ###### Repaso práctico de modificación y manejo de **strings, for, condicionales, funciones lambda, etc**

# %%
#Cambiar nombre del DF multiindex a uno solo
print(df_multi.columns)
# Out:
# MultiIndex([(       'Close',  'AAPL'),
#             (       'Close',  'AMZN'),
#             (       'Close', 'GOOGL'),
#             (   'Dividends',  'AAPL'),
#             (   'Dividends',  'AMZN'),
#             (   'Dividends', 'GOOGL'),
#             (        'High',  'AAPL'),
#             (        'High',  'AMZN'),
#             (        'High', 'GOOGL'),
#             (         'Low',  'AAPL'),
#             (         'Low',  'AMZN'),
#             (         'Low', 'GOOGL'),
#             (        'Open',  'AAPL'),
#             (        'Open',  'AMZN'),
#             (        'Open', 'GOOGL'),
#             ('Stock Splits',  'AAPL'),
#             ('Stock Splits',  'AMZN'),
#             ('Stock Splits', 'GOOGL'),
#             (      'Volume',  'AAPL'),
#             (      'Volume',  'AMZN'),
#             (      'Volume', 'GOOGL')],
#            names=['Price', 'Ticker'])

# %%
#Generar lista de nuevos nombres
new_colnames = ['_'.join(i) for i in df_multi.columns]
new_colnames
# Out:
# ['Close_AAPL',
#  'Close_AMZN',
#  'Close_GOOGL',
#  'Dividends_AAPL',
#  'Dividends_AMZN',
#  'Dividends_GOOGL',
#  'High_AAPL',
#  'High_AMZN',
#  'High_GOOGL',
#  'Low_AAPL',
#  'Low_AMZN',
#  'Low_GOOGL',
#  'Open_AAPL',
#  'Open_AMZN',
#  'Open_GOOGL',
#  'Stock Splits_AAPL',
#  'Stock Splits_AMZN',
#  'Stock Splits_GOOGL',
#  'Volume_AAPL',
#  'Volume_AMZN',
#  'Volume_GOOGL']

# %%
#Asignamos nuevos nombre al DF
df_multi.columns =  new_colnames
df_multi
# Out:
#             Close_AAPL  Close_AMZN  Close_GOOGL  Dividends_AAPL  \
# Date
# 2024-03-27  172.495499  179.830002   150.152115             0.0
# 2024-03-28  170.674088  180.380005   150.211838             0.0
# 2024-04-01  169.230927  180.970001   154.750153             0.0
# 2024-04-02  168.046494  180.690002   153.824570             0.0
# 2024-04-03  168.852707  182.410004   154.182846             0.0
# ...                ...         ...          ...             ...
# 2025-03-20  214.100006  194.949997   162.800003             0.0
# 2025-03-21  218.270004  196.210007   163.990005             0.0
# 2025-03-24  220.729996  203.259995   167.679993             0.0
# 2025-03-25  223.750000  205.710007   170.559998             0.0
# 2025-03-26  221.529999  201.130005   165.059998             0.0
#
#             Dividends_AMZN  Dividends_GOOGL   High_AAPL   High_AMZN  \
# Date
# 2024-03-27             0.0              0.0  172.784144  180.000000
# ...

# %%
#Close
list_close = [col for col in df_multi.columns  if 'Close' in col]
print(list_close)
# Out:
# ['Close_AAPL', 'Close_AMZN', 'Close_GOOGL']

# %%
#Creación de DF close
df_close =  df_multi[list_close]
print(df_close)
# Out:
#             Close_AAPL  Close_AMZN  Close_GOOGL
# Date
# 2024-03-27  172.495499  179.830002   150.152115
# 2024-03-28  170.674088  180.380005   150.211838
# 2024-04-01  169.230927  180.970001   154.750153
# 2024-04-02  168.046494  180.690002   153.824570
# 2024-04-03  168.852707  182.410004   154.182846
# ...                ...         ...          ...
# 2025-03-20  214.100006  194.949997   162.800003
# 2025-03-21  218.270004  196.210007   163.990005
# 2025-03-24  220.729996  203.259995   167.679993
# 2025-03-25  223.750000  205.710007   170.559998
# 2025-03-26  221.529999  201.130005   165.059998
#
# [250 rows x 3 columns]

# %% [markdown]
# ###### **Transformación de formatos de DF y pivoteo: Long- Wide**
#
# * Formatos de Datos: Wide vs Long
#
# **¿Qué es Wide?**
#
# - En el formato **wide**, cada variable o categoría aparece como una columna.
# - Frecuente en reportes y tablas resumen.
#
# Ejemplo:
#
# | Persona | Año_2020 | Año_2021 | Año_2022 |
# |---------|----------|----------|----------|
# | Ana     |   10     |    15    |   20     |
# | Juan    |   5      |    7     |   10     |
#
#
# **¿Qué es Long?**
#
# - En el formato **long**, los niveles de una variable se codifican en filas.
# - Tambien conocido como Tidy:
#
#    Los datos tidy cumplen:
# > 1. Cada variable es una columna.
# > 2. Cada observación es una fila.
# > 3. Cada valor está en una celda.
#
#
#
# Ejemplo Long (tidy):
#
# | Persona | Año   | Valor |
# |---------|-------|-------|
# | Ana     | 2020  | 10    |
# | Ana     | 2021  | 15    |
# | Ana     | 2022  | 20    |
# | Juan    | 2020  | 5     |
# | Juan    | 2021  | 7     |
# | Juan    | 2022  | 10    |
#
#
# > **Recomendado para análisis, visualización y modelado.**

# %% [markdown]
# **Uso de las funciones `melt()` y  `pivot() `**
#
#
# Sintáxis
#
# 🔄 melt() — Convertir de Wide a Long
#
# ```Python
#
# pd.melt(
#         frame,                  # DataFrame original
#         id_vars=None,            # Columnas que NO se van a     modificar (se mantienen fijas)
#         value_vars=None,         # Columnas que se van a modificar    (opcional, si no se pone son todas las que no estén en     id_vars)
#         var_name=None,           # Nombre de la nueva columna que     contendrá los nombres de las columnas columnas
#         value_name='value'       # Nombre de la nueva columna que contendrá los valores
# )
# ```
#
# 🔄 pivot() — Convertir de Long a Wide
#
# ```Python
# df.pivot(
#           index=None,    # Columnas que serán las filas       (identificadores)
#           columns=None,  # Columna que se va a convertir en nombres       de columnas
#           values=None    # Columna que se va a convertir en los valores de las celdas
# )
# ```

# %%
import pandas as pd
#DF wide
df_wide = pd.DataFrame({
                        'Persona': ['Ana', 'Juan'],
                        'Año_2020': [10, 5],
                        'Año_2021': [15, 7],
                        'Año_2022': [20, 10]
                         })

print(df_wide)
# Out:
#   Persona  Año_2020  Año_2021  Año_2022
# 0     Ana        10        15        20
# 1    Juan         5         7        10

# %%
#Convertir de wide a long
df_long = df_wide.melt(id_vars='Persona',
                       var_name='Año',
                       value_name='Score')

# Limpiamos el nombre de las columnas
df_long['Año'] = df_long['Año'].str.replace('Año_', '')

df_long
# Out:
#   Persona   Año  Score
# 0     Ana  2020     10
# 1    Juan  2020      5
# 2     Ana  2021     15
# 3    Juan  2021      7
# 4     Ana  2022     20
# 5    Juan  2022     10

# %% [markdown]
# * Ejemplo de long a wide

# %%
df_wide2 = df_long.pivot(index='Persona',
                         columns='Año',
                         values='Score'
                        ).reset_index()

print(df_wide2)
# Out:
# Año Persona  2020  2021  2022
# 0       Ana    10    15    20
# 1      Juan     5     7    10

# %% [markdown]
# *  **Ejemplo 2: Convertir de formato wide a long el Data Frame de preciones de activos**

# %%
print(df_close.shape)
# Out:
# (250, 4)

# %%
#Quitar Date de índice
df_close = df_close.reset_index()

#Convertir de wide a long
df_close_long = df_close.melt(id_vars='Date',
                              var_name='Empresa',
                              value_name='Precio cierre')
# Out:
#         Date     Empresa  Precio cierre
# 0 2024-03-27  Close_AAPL     172.495499
# 1 2024-03-28  Close_AAPL     170.674088
# 2 2024-04-01  Close_AAPL     169.230927
# 3 2024-04-02  Close_AAPL     168.046494
# 4 2024-04-03  Close_AAPL     168.852707
# 5 2024-04-04  Close_AAPL     168.026627
# 6 2024-04-05  Close_AAPL     168.783035
# 7 2024-04-08  Close_AAPL     167.658340
# 8 2024-04-09  Close_AAPL     168.872604
# 9 2024-04-10  Close_AAPL     166.991470

# %%
#Limpiamos nombres de empresas
df_close_long['Empresa'] = df_close_long['Empresa'].str.replace('Close_', '')

df_close_long
# Out:
#           Date Empresa  Precio cierre
# 0   2024-03-27    AAPL     172.495499
# 1   2024-03-28    AAPL     170.674088
# 2   2024-04-01    AAPL     169.230927
# 3   2024-04-02    AAPL     168.046494
# 4   2024-04-03    AAPL     168.852707
# ..         ...     ...            ...
# 745 2025-03-20   GOOGL     162.800003
# 746 2025-03-21   GOOGL     163.990005
# 747 2025-03-24   GOOGL     167.679993
# 748 2025-03-25   GOOGL     170.559998
# 749 2025-03-26   GOOGL     165.059998
#
# [750 rows x 3 columns]

# %%
print(df_close.shape, df_close_long.shape)
# Out:
# (250, 4) (750, 3)

# %% [markdown]
# **Ejemplo 2: Convertir de formato long a wide preciones de activos**

# %%
df_close_wide = df_close_long.pivot(index='Date',
                                    columns='Empresa',
                                    values='Precio cierre')

df_close_wide.head(10)
# Out:
# Empresa           AAPL        AMZN       GOOGL
# Date
# 2024-03-27  172.495499  179.830002  150.152115
# 2024-03-28  170.674088  180.380005  150.211838
# 2024-04-01  169.230927  180.970001  154.750153
# 2024-04-02  168.046494  180.690002  153.824570
# 2024-04-03  168.852707  182.410004  154.182846
# 2024-04-04  168.026627  180.000000  149.813751
# 2024-04-05  168.783035  185.070007  151.774368
# 2024-04-08  167.658340  185.190002  154.113205
# 2024-04-09  168.872604  185.669998  155.854858
# 2024-04-10  166.991470  185.949997  155.397064

# %% [markdown]
# ### **5.4.2 . Introducción a la importación de datos de APIs y sitios WEB (Inegi, Banxico, ADIP)**
#
# #### 5.4.2.1 **¿Qué es una API?**
#
# Una **API (Application Programming Interface)** es un puente que permite que un programa (en este caso un código) se comunique directamente con una base de datos o servicio.
#
# ![image.png](data:image/png;base64,...)
#
# En nuestro caso, vamos a conectar Python con los datos públicos de:
#
# - INEGI (Indicadores económicos y sociodemográficos de México)
#
# - Banxico (Indicadores financieros y económicos, tipo de cambio, tasas de interés, inflación, etc.)

# %% [markdown]
# **API Banxico**
#
#  1 . Necesitamos un token para interactuar con la API:
#
#   [TOKEN ](https://www.banxico.org.mx/SieAPIRest/service/v1/token)
#
#
#   2. En Python utilizaremos la paquetería `request`
#      - La paquetería permite enviar solicitudes HTTP y manejar respuestas de
#         servidores web.

# %%
import requests

# %% [markdown]
# 3. Generar solicitud a la API

# %%
# Parámetros
# -------------------------
token = "08c4a52202cd27cd41ca5f37017cf6b88988f78c5fa1d03840492732c0eef9ec"
serie = "SE5729"
serie2 = "SF4371"
# -------------------------
# Consulta API
# -------------------------

url = f"https://www.banxico.org.mx/SieAPIRest/service/v1/series/{serie},{serie2}/datos"
headers = {'Bmx-Token': token}

#Generar request
response = requests.get(url, headers=headers)


#Respuesta en formato JSON
json_response = response.json()
json_response.head(5)
# Out:
# {'bmx': {'series': [{'idSerie': 'SF4371',
#     'titulo': 'BANCO DE MEXICO,FINANCIAMIENTO EN MONEDA EXTRANJERA INTERNO, AL SECTOR PUBLICO, GOBIERNO FEDERAL',
#     'datos': [{'fecha': '01/12/1980', 'dato': '85,810.00'},
#      {'fecha': '01/01/1981', 'dato': '84,617.00'},
#      {'fecha': '01/02/1981', 'dato': '87,431.00'},
#      {'fecha': '01/03/1981', 'dato': '87,472.00'},
#      {'fecha': '01/04/1981', 'dato': '86,267.00'},
#      {'fecha': '01/05/1981', 'dato': '86,485.00'},
#      {'fecha': '01/06/1981', 'dato': '112,055.00'},
#      {'fecha': '01/07/1981', 'dato': '141,018.00'},
#      {'fecha': '01/08/1981', 'dato': '176,660.00'},
#      {'fecha': '01/09/1981', 'dato': '184,188.00'},
#      {'fecha': '01/10/1981', 'dato': '193,404.00'},
#      {'fecha': '01/11/1981', 'dato': '202,377.00'},
#      {'fecha': '01/12/1981', 'dato': '205,376.00'},
#      {'fecha': '01/01/1982', 'dato': '223,220.00'},
#      {'fecha': '01/02/1982', 'dato': '392,086.00'},
# ...

# %%
# Extraer datos
d_emp_maqui = json_response['bmx']['series'][0]['datos']
d_emp_maqui

d_emp_maqui
# Out:
# [{'fecha': '01/01/1980', 'dato': '113,797'},
#  {'fecha': '01/02/1980', 'dato': '115,238'},
#  {'fecha': '01/03/1980', 'dato': '118,540'},
#  {'fecha': '01/04/1980', 'dato': '119,903'},
#  {'fecha': '01/05/1980', 'dato': '118,574'},
#  {'fecha': '01/06/1980', 'dato': '119,564'},
#  {'fecha': '01/07/1980', 'dato': '119,175'},
#  {'fecha': '01/08/1980', 'dato': '119,106'},
#  {'fecha': '01/09/1980', 'dato': '120,330'},
#  {'fecha': '01/10/1980', 'dato': '122,279'},
#  {'fecha': '01/11/1980', 'dato': '124,043'},
#  {'fecha': '01/12/1980', 'dato': '123,879'},
#  {'fecha': '01/01/1981', 'dato': '121,969'},
#  {'fecha': '01/02/1981', 'dato': '123,629'},
#  {'fecha': '01/03/1981', 'dato': '128,252'},
#  {'fecha': '01/04/1981', 'dato': '129,047'},
#  {'fecha': '01/05/1981', 'dato': '131,344'},
#  {'fecha': '01/06/1981', 'dato': '132,853'},
#  {'fecha': '01/07/1981', 'dato': '134,435'},
#  {'fecha': '01/08/1981', 'dato': '134,644'},
#  {'fecha': '01/09/1981', 'dato': '135,374'},
# ...

# %%
# Convertir a DataFrame
df_emp_maqui = pd.DataFrame(d_emp_maqui)

df_emp_maqui.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fecha   321 non-null    object
#  1   dato    321 non-null    object
# dtypes: object(2)
# memory usage: 5.1+ KB

# %%
# Limpiar columnas
df_emp_maqui.columns = ['Fecha', 'Ocupados_Industria_Maquiladora']

# %%
#Convertir a fecha
df_emp_maqui['Fecha'] = pd.to_datetime(df_emp_maqui['Fecha'], dayfirst=True)
#Convertir a numerico
df_emp_maqui['Ocupados_Industria_Maquiladora'] = pd.to_numeric(df_emp_maqui['Ocupados_Industria_Maquiladora'].str.replace(',', ''))

#Listo para analizar serie
print(df_emp_maqui.info())
df_emp_maqui.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 2 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Fecha                           321 non-null    datetime64[ns]
#  1   Ocupados_Industria_Maquiladora  321 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 5.1 KB
# None
#        Fecha  Ocupados_Industria_Maquiladora
# 0 1980-01-01                          113797
# 1 1980-02-01                          115238
# 2 1980-03-01                          118540
# 3 1980-04-01                          119903
# 4 1980-05-01                          118574
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6['index'].plot(kind='hist', bins=20, title='index')
# ...

# %%
# ,{serie2}
# dfs = []
# for serie in json_response['bmx']['series']:
#     df_temp = pd.DataFrame(serie['datos'])
#     df_temp.columns = ['Fecha', serie['titulo']]
#     df_temp['Fecha'] = pd.to_datetime(df_temp['Fecha'], dayfirst=True)
#     df_temp[serie['titulo']] = pd.to_numeric(df_temp[serie['titulo']], errors='coerce')
#     dfs.append(df_temp)
# dfs
# Out:
# [         Fecha  \
#  0   1980-01-01
#  1   1980-02-01
#  2   1980-03-01
#  3   1980-04-01
#  4   1980-05-01
#  ..         ...
#  316 2006-05-01
#  317 2006-06-01
#  318 2006-07-01
#  319 2006-08-01
#  320 2006-09-01
#
#       Personal ocupado en la industria maquiladora Productos procesados Promedio del periodo Total nacional Productos alimenticios
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  316                                                NaN
#  317                                                NaN
#  318                                                NaN
#  319                                                NaN
#  320                                                NaN
#
# ...

# %% [markdown]
# ###### **API INEGI**
#
# 1. Configuración de la API
#
# * URL base para las consultas a la API en el siguiente link:
#
# [API del Banco de Indicadores](https://www.inegi.org.mx/servicios/api_indicadores.html#idMetodoIndicadoresInegi)
#
# * Generación de TOKEN en:
#
# [Generar Token](https://www.inegi.org.mx/app/api/denue/v1/tokenVerify.aspx)

# %%
#Librerías
import requests
import pandas as pd
import json
from datetime import datetime

#1. Configuración de la API del INEGI
#La URL base para las peticiones a la API
BASE_URL = "https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/"

# Token de acceso (debes registrarte en el portal del INEGI para obtener uno)
# https://www.inegi.org.mx/servicios/api_indicadores/
TOKEN = "tu_token_aquí"
mi_token = "afd53ab7-a173-4589-ad14-ecbb01fd4358"

# %% [markdown]
# 2. Consulta a la API

# %%
#Contrucción de URL
#Definir indicador
#indicador_id = '6200240539'
indicador_id = '1002000026' #nacimientos registrados
#URL final
url_final = f"{BASE_URL}{indicador_id}/es/0700/false/BISE/2.0/{mi_token}?type=json"
print(url_final)

#Realizar consulta con función request
res_inegi_ind = requests.get(url_final)
print(res_inegi_ind) #Si obtenemos una respuesta de clave 200 es que es correcta
# Out:
# https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/1002000026/es/0700/false/BISE/2.0/afd53ab7-a173-4589-ad14-ecbb01fd4358?type=json
# <Response [200]>

# %%
#Convertir respuesta a json
datos_indicador = res_inegi_ind.json()
print(datos_indicador)
# Out:
# {'Header': {'Name': 'Datos compactos BISE', 'Email': 'atencion.usuarios@inegi.org.mx'}, 'Series': [{'INDICADOR': '1002000026', 'FREQ': '3', 'TOPIC': '126', 'UNIT': '1049', 'UNIT_MULT': '', 'NOTE': '6', 'SOURCE': '2066', 'LASTUPDATE': '20/03/2024 12:00:00 a. m.', 'STATUS': None, 'OBSERVATIONS': [{'TIME_PERIOD': '1994', 'OBS_VALUE': '2904389.00000000000000000000', 'OBS_EXCEPTION': None, 'OBS_STATUS': '3', 'OBS_SOURCE': '', 'OBS_NOTE': '', 'COBER_GEO': '0700'}, {'TIME_PERIOD': '1995', 'OBS_VALUE': '2750444.00000000000000000000', 'OBS_EXCEPTION': None, 'OBS_STATUS': '3', 'OBS_SOURCE': '', 'OBS_NOTE': '', 'COBER_GEO': '0700'}, {'TIME_PERIOD': '1996', 'OBS_VALUE': '2707718.00000000000000000000', 'OBS_EXCEPTION': None, 'OBS_STATUS': '3', 'OBS_SOURCE': '', 'OBS_NOTE': '', 'COBER_GEO': '0700'}, {'TIME_PERIOD': '1997', 'OBS_VALUE': '2698425.00000000000000000000', 'OBS_EXCEPTION': None, 'OBS_STATUS': '3', 'OBS_SOURCE': '', 'OBS_NOTE': '', 'COBER_GEO': '0700'}, {'TIME_PERIOD': '1998', 'OBS_VALUE
# ...

# %% [markdown]
# 3. Extracción de datos

# %%
#Extracción de datos
list_datos = datos_indicador['Series'][0]['OBSERVATIONS']

type(list_datos)
print(list_datos)
# Out:
# [{'TIME_PERIOD': '1994', 'OBS_VALUE': '2904389.00000000000000000000', 'OBS_EXCEPTION': None, 'OBS_STATUS': '3', 'OBS_SOURCE': '', 'OBS_NOTE': '', 'COBER_GEO': '0700'}, {'TIME_PERIOD': '1995', 'OBS_VALUE': '2750444.00000000000000000000', 'OBS_EXCEPTION': None, 'OBS_STATUS': '3', 'OBS_SOURCE': '', 'OBS_NOTE': '', 'COBER_GEO': '0700'}, {'TIME_PERIOD': '1996', 'OBS_VALUE': '2707718.00000000000000000000', 'OBS_EXCEPTION': None, 'OBS_STATUS': '3', 'OBS_SOURCE': '', 'OBS_NOTE': '', 'COBER_GEO': '0700'}, {'TIME_PERIOD': '1997', 'OBS_VALUE': '2698425.00000000000000000000', 'OBS_EXCEPTION': None, 'OBS_STATUS': '3', 'OBS_SOURCE': '', 'OBS_NOTE': '', 'COBER_GEO': '0700'}, {'TIME_PERIOD': '1998', 'OBS_VALUE': '2668428.00000000000000000000', 'OBS_EXCEPTION': None, 'OBS_STATUS': '3', 'OBS_SOURCE': '', 'OBS_NOTE': '', 'COBER_GEO': '0700'}, {'TIME_PERIOD': '1999', 'OBS_VALUE': '2769089.00000000000000000000', 'OBS_EXCEPTION': None, 'OBS_STATUS': '3', 'OBS_SOURCE': '', 'OBS_NOTE': '', 'COBER_GEO': '070
# ...

# %% [markdown]
# **Ejercicio**
#
# 1. ¿Cómo obteno el primer elemenot de una lista?
#
# 2. ¿Cómo obtengo el segundo elemento de una lista?

# %%
#Convertir a DataFrame

# Convertir a DataFrame
df_api_ind = pd.DataFrame(list_datos)
#print(df_api_ind .info())
#Renombro columnas
df_api_ind.rename(columns={'TIME_PERIOD': 'Año', 'OBS_VALUE': 'Nacimientos'}, inplace=True)
#Filtro solo año y valor del indicador
df_api_ind = df_api_ind[['Año', 'Nacimientos']]
df_api_ind.head(5)
# Out:
#      Año                   Nacimientos
# 0   1994  2904389.00000000000000000000
# 1   1995  2750444.00000000000000000000
# 2   1996  2707718.00000000000000000000
# 3   1997  2698425.00000000000000000000
# 4   1998  2668428.00000000000000000000
# 5   1999  2769089.00000000000000000000
# 6   2000  2798339.00000000000000000000
# 7   2001  2767610.00000000000000000000
# 8   2002  2699084.00000000000000000000
# 9   2003  2655894.00000000000000000000
# 10  2004  2625056.00000000000000000000
# 11  2005  2567906.00000000000000000000
# 12  2006  2505939.00000000000000000000
# 13  2007  2655083.00000000000000000000
# 14  2008  2636110.00000000000000000000
# 15  2009  2577214.00000000000000000000
# 16  2010  2643908.00000000000000000000
# 17  2011  2586287.00000000000000000000
# 18  2012  2498880.00000000000000000000
# 19  2013  2478889.00000000000000000000
# 20  2014  2463420.00000000000000000000
# 21  2015  2353596.00000000000000000000
# 22  2016  2293708.00000000000000000000
# ...

# %% [markdown]
# ##### API INEGI-DENUE
# Paso para descarga de datos del Directorio Estadístico Nacional de Unidades Económicas (DENUE)
#
# 1. Definición de parámetros
#   - Generación el token en: [TOKEN Denue](https://www.inegi.org.mx/app/api/denue/v1/tokenVerify.aspx)
#   - Coordenadas de partida
#   - Radio

# %%
#Definición de parámetros
#TOKEN de DENUE
token = 'afd53ab7-a173-4589-ad14-ecbb01fd4358'
#Coordenadad de partidad
#UAM azc
lat= 19.5031
lon = -99.1870
#Radio de  kms (5 km máximo)
radio = 5000
#Establecimientos
tipo = 'oxxo'
#URL para request
url = f'https://www.inegi.org.mx/app/api/denue/v1/consulta/Buscar/{tipo}/{lat},{lon}/{radio}/{token}'

# %% [markdown]
# 2. Consulta a la API de DENUE

# %%
#Generación de consulta
respuesta = requests.get(url)
#Formato json
datos_denue = respuesta.json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f7805c072e31> in <cell line: 0>()
#       1 #Generación de consulta
# ----> 2 respuesta = requests.get(url)
#       3 #Formato json
#       4 datos_denue = respuesta.json()
#
# NameError: name 'url' is not defined

# %% [markdown]
# 3. Extracción de datos

# %%
df_api_denue= pd.DataFrame(datos_denue)
df_api_denue.info()
df_api_denue
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CLEE                 197 non-null    object
#  1   Id                   197 non-null    object
#  2   Nombre               197 non-null    object
#  3   Razon_social         197 non-null    object
#  4   Clase_actividad      197 non-null    object
#  5   Estrato              197 non-null    object
#  6   Tipo_vialidad        197 non-null    object
#  7   Calle                197 non-null    object
#  8   Num_Exterior         197 non-null    object
#  9   Num_Interior         197 non-null    object
#  10  Colonia              197 non-null    object
#  11  CP                   197 non-null    object
#  12  Ubicacion            197 non-null    object
#  13  Telefono             197 non-null    object
#  14  Correo_e             197 non-null    object
# ...

# %% [markdown]
# #### **5.4.2.2 Descargas de datos de sitios web**
#
#
# Ejemplo con la Encuesta Nacional de Ocupación y Empleo (ENOE)
#
# 1. Para la consulta utilizamos la funcion `get()` de la librería `requests`.
#
# - Realiza una petición HTTP GET a la URL especificada en una variable definida
#
# - El resultado se almacena en una variable que contendrá los bytes del archivo ZIP
#
# Sintáxis
#
# ```Python
#
# url = 'url de datos de interes'
# #Consulta
# request_info = requests.get(url_data).content
#
# #Se agrega la función get que extrae el contenido binario de la respuesta HTTP
#
# ```
#
# 2. Creación del file ZIP en memoria
#
# - Con la función `BytesIO()`  se crea un objeto tipo "archivo" en memoria a partir de los bytes descargados de la función `ZipFile() ` el cual toma este objeto y lo interpreta como un archivo ZIP.
#
# - El resultado es un objeto zip_form que te permite acceder a los contenidos del ZIP file sin guardarlo en el disco.
#
# Sintáxis
#
# ```Python
# zip_form = ZipFile(BytesIO(request_dats))
# ```

# %%
#Realizar descarga

from zipfile import ZipFile
from io import BytesIO
import requests
#Definimos URL
url_data = 'https://www.inegi.org.mx/contenidos/programas/enoe/15ymas/microdatos/enoe_2024_trim3_csv.zip'

#Consulta de datos
request_data = requests.get(url_data).content
#Zip File
zip_form = ZipFile(BytesIO(request_data))

# %%
#Nombres de los fiels en el ZIP
for i in zip_form.filelist:
  print(i)
# Out:
# <ZipInfo filename='ENOE_COE1T324.csv' compress_type=deflate external_attr=0x20 file_size=129587506 compress_size=7726470>
# <ZipInfo filename='ENOE_COE2T324.csv' compress_type=deflate external_attr=0x20 file_size=66058196 compress_size=5091409>
# <ZipInfo filename='ENOE_HOGT324.csv' compress_type=deflate external_attr=0x20 file_size=15814921 compress_size=1440893>
# <ZipInfo filename='ENOE_SDEMT324.csv' compress_type=deflate external_attr=0x20 file_size=115587224 compress_size=16635205>
# <ZipInfo filename='ENOE_VIVT324.csv' compress_type=deflate external_attr=0x20 file_size=11583296 compress_size=1094068>

# %% [markdown]
# 3. **Carga de datos  de forma directa**
#
# Es posible cargar un archivo directamente del ZIP comprimido sin necesidad de extraerlo a disco. Esto es muy útil para ahorrar espacio y tiempo, especialmente cuando trabajas con archivos grandes o cuando solo necesitas uno de los muchos archivos contenidos en el ZIP.
#
# Sintáxis
#
# ```Python
# #Nombre del file
# nombre_archivo = "NOMBRE_DEL_ARCHIVO.csv"
# #Cargar datos
# with zip_form.open(nombre_archivo) as file:
#     df = pd.read_csv(file, encoding='latin-1')
#
# #Latin  especifica que el archivo CSV está codificado en latin-1 (también conocido como ISO-8859-1),
# #que es común para archivos generados en entornos hispanohablantes como el INEGI
#
# ```

# %%
#Cargar archivo CSV
with zip_form.open('ENOE_SDEMT324.csv') as file:
    df_enoe_2024t3 = pd.read_csv(file, encoding='latin-1')

print(df_enoe_2024t3.head(20))
# Out:
# <ipython-input-27-e4c426d758c8>:3: DtypeWarning: Columns (2,22,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_enoe_2024t3 = pd.read_csv(file, encoding='latin-1')
#     r_def loc mun  est  est_d_tri est_d_men  ageb  t_loc_tri t_loc_men  cd_a  \
# 0       0       6   30        676       637     0          1         1     1
# 1       0      10   30        124               0          1               1
# 2       0       6   30        124               0          1               1
# 3       0       6   30        124               0          1               1
# 4       0       6   30        676       637     0          1         1     1
# 5       0      11   20        123               0          1               1
# 6       0       6   30        676       637     0          1         1     1
# 7       0       7   30        676       637     0          1         1     1
# ...

# %% [markdown]
# **Ejercicio**
#
# - ¿Cuántas columnas tengo y en cuales tengo valores NA?

# %% [markdown]
# #### **5.4.3 Carga de archivos de Texto y Excel (.txt, .csv, .xlsx y .xls)**
#
# En este capítulo exploraremos cómo trabajar con diferentes formatos de archivos comúnmente utilizados para el análisis de datos en Python. Nos enfocaremos en archivos .txt, .csv, .xlsx y .xls

# %% [markdown]
# - Lectura de archivos CSV
#
#    Para ello se utiliza la función `pd.read_csv()`
#
#    Argumentos de la función:
#
# ```Python
# df = pd.read_csv('archivo.csv',
#                  encoding='latin-1',       # Codificación del archivo
#                  sep=',',                  # Separador de columnas
#                  decimal='.',              # Separador decimal
#                  header=0,                 # Fila que contiene los nombres de columnas
#                  skiprows=[1, 2],          # Filas a saltar
#                  nrows=100,                # Número de filas a leer
#                  usecols=['col1', 'col2'], # Columnas específicas a leer
#                  na_values=['NA', '-'],    # Valores que serán interpretados como NaN
#                  dtype={'col1': str}       # Tipos de datos para columnas específicas
#                 )
# ```
# - Lectura de archivos (.txt)
#
# Los archivos .txt también son comunes y pueden tener diferentes formatos.
#
#    Para ello se utiliza la función `pd.read_csv()`
#
#    Argumentos de la función:
#
#    ```Python
#    df = pd.read_csv('archivo.txt', sep='\t')
#
#    ```
# - **Lectura de archivos Excel (.xlsx y .xls)**
#
# Pandas facilita la lectura de archivos Excel a través de su función `read_excel()` .
#
#
# Sintáxis
#
#
# ```Python
# #Básica
# df = pd.read_excel('archivo.xlsx')
#
# #Argumentos adicionales
# df = pd.read_excel('archivo.xlsx',
#                    sheet_name='Hoja1',     # Nombre de la hoja
#                    header=0,               # Fila que contiene los nombres de columnas
#                    skiprows=2,             # Filas a saltar
#                    usecols='A:C',          # Columnas a leer (formato Excel)
#                    nrows=100,              # Número de filas a leer
#                    na_values=['NA', '-']   # Valores que serán interpretados como NaN
#                   )
# ```
#
# Ejemplo con la ENOE:

# %%
#Ejemplo ENOE

#Librearia para conectar con goodle drive
from google.colab import drive

#Autorización
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Leemos
df = pd.read_csv("/content/drive/My Drive/nombre_del_archivo.csv")
print(df.head())

# %% [markdown]
# ##### Exportación de archivos a múltiples formatos
# Pandas también facilita la escritura o exportación de de DataFrames a diferentes formatos.
#
# - Escritura a CSV
#
# ```Python
# df.to_csv('nuevo_archivo.csv', index=False)
# ```
# - Escritura a Excel
#
# ```Python
# df.to_excel('nuevo_archivo.xlsx', index=False, sheet_name='Datos')
# ```
#
# - Escritura a texto delimitado por tabuladores
#
# ```Pytho
# df.to_csv('nuevo_archivo.txt', sep='\t', index=False)
# ```
